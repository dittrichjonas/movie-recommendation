# %% [markdown]
# **Implementierung Kollaboratives speicherbasiertes System mit K = 40**

# %% [markdown]
# *Installation Surprise Bibliothek*

# %%
pip install scikit-surprise # Quelle 1
# Out:
# Collecting scikit-surprise
#   Downloading scikit_surprise-1.1.4.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 5.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.4.0)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.25.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.4)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (pyproject.toml) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp310-cp310-linux_x86_64.whl size=2357246 sha256=b2038af018756f56f0f7a5ac34f19332a1c96e24c73fc2f72aa7f8125aaff6b7
#   Stored in directory: /root/.cache/pip/wheels/4b/3f/df/6acbf0a40397d9bf3ff97f582cc22fb9ce66adde75bc71fd54
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.4

# %% [markdown]
# *Import benötigte Bibliotheken*
#
#
# Importiert werden die für die Umsetzung benötigten Python Bibliotheken Pandas und Surprise

# %%
import pandas as pd # Quelle 2
from surprise.model_selection import cross_validate # Quelle 3
from surprise import Dataset, Reader, accuracy, KNNBasic, NormalPredictor, KNNWithMeans # Quelle 3

# %% [markdown]
# *Datenvorverarbeitung*
#
# Die Bewertungsdaten werden eingelesen und in ein Format überführt, mit welchem Surprise arbeiten kann.

# %%
ratings = pd.read_csv('ratings.csv') # Quelle 4

# %%
reader = Reader(rating_scale=(0.5, 5.0)) # Quelle 5
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader) # Quelle 5

# %% [markdown]
# *Konfiguration der Ähnlichkeit Einstellungen*
#
# Die Ähnlichkeits Konfigurationen werden erstellt und intitialisiert.

# %%
#Kosinus Ähnlichkeit Item Based
sim_options_knnbasic_ib_cos = {"name": "cosine", 'user_based': False} # Quelle 6,7

# %%
#Kosinus Ähnlichkeit User Based
sim_options_knnbasic_ub_cos = {"name": "cosine", 'user_based': True} # Quelle 6,7

# %%
#Kosinus Ähnlichkeit Item Based
sim_options_knnbasic_ib_msd = {"name": "cosine", 'user_based': False} # Quelle 6,7

# %%
#Kosinus Ähnlichkeit User Based
sim_options_knnbasic_ub_msd = {"name": "cosine", 'user_based': True} # Quelle 6,7

# %%
#Kosinus Ähnlichkeit Item Based
sim_options_knnbasic_ib_prs = {"name": "cosine", 'user_based': False} # Quelle 6,7

# %%
#Kosinus Ähnlichkeit User Based
sim_options_knnbasic_ub_prs = {"name": "cosine", 'user_based': True} # Quelle 6,7

# %% [markdown]
# *Erstellung Algorithmus KNNBasic*
#
# Die Algorithmen werden mit den bereits konfigurierten Ähnlichkeits Optionen erstellt.

# %%
algo_knnbasic_ib_cos = KNNBasic(sim_options=sim_options_knnbasic_ib_cos, k = 40) #Quelle 8

# %%
algo_knnbasic_ub_cos = KNNBasic(sim_options=sim_options_knnbasic_ub_cos, k = 40) #Quelle 8

# %%
algo_knnbasic_ib_msd = KNNBasic(sim_options=sim_options_knnbasic_ib_msd, k = 40) #Quelle 8

# %%
algo_knnbasic_ub_msd = KNNBasic(sim_options=sim_options_knnbasic_ub_msd, k = 40) #Quelle 8

# %%
algo_knnbasic_ib_prs = KNNBasic(sim_options=sim_options_knnbasic_ib_prs, k = 40) #Quelle 8

# %%
algo_knnbasic_ub_prs = KNNBasic(sim_options=sim_options_knnbasic_ub_prs, k = 40) #Quelle 8

# %% [markdown]
# *Evaluierungs Parameter: RMSE, MAE, MSE, FCP, Test-Time, Train-Time (KNNBasic)*
#
# Die Cross Validierung wird konfiguriert und durchgeführt.

# %%
cross_validate(algo_knnbasic_ib_cos, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0069  0.9973  0.9914  0.9891  0.9914  0.9952  0.0065
# MAE (testset)     0.7832  0.7747  0.7727  0.7710  0.7715  0.7746  0.0045
# MSE (testset)     1.0139  0.9947  0.9828  0.9783  0.9829  0.9905  0.0129
# FCP (testset)     0.4472  0.4542  0.4595  0.4557  0.4540  0.4541  0.0040
# Fit time          8.93    5.84    5.64    5.69    5.69    6.36    1.29
# Test time         8.39    8.11    8.07    8.18    8.13    8.17    0.11
# {'test_rmse': array([1.0069187 , 0.99733622, 0.99135453, 0.98906792, 0.9914334 ]),
#  'test_mae': array([0.78316357, 0.77473645, 0.77265812, 0.77096546, 0.77148462]),
#  'test_mse': array([1.01388526, 0.99467954, 0.9827838 , 0.97825535, 0.9829402 ]),
#  'test_fcp': array([0.44720407, 0.45418228, 0.45954847, 0.45570307, 0.45402853]),
#  'fit_time': (8.933982849121094,
#   5.837600469589233,
#   5.641920328140259,
#   5.688377857208252,
#   5.685413599014282),
#  'test_time': (8.392765522003174,
#   8.108809232711792,
#   8.065198421478271,
#   8.17520523071289,
#   8.13007140159607)}

# %%
cross_validate(algo_knnbasic_ub_cos, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9934  0.9977  1.0023  0.9870  0.9897  0.9940  0.0055
# MAE (testset)     0.7684  0.7697  0.7744  0.7610  0.7660  0.7679  0.0044
# MSE (testset)     0.9868  0.9954  1.0047  0.9742  0.9794  0.9881  0.0109
# FCP (testset)     0.6492  0.6571  0.6498  0.6566  0.6510  0.6527  0.0034
# Fit time          0.19    0.24    0.23    0.31    0.20    0.24    0.04
# Test time         1.60    1.42    2.37    1.53    1.40    1.67    0.36
# {'test_rmse': array([0.99339812, 0.99769146, 1.00233477, 0.98702715, 0.98965491]),
#  'test_mae': array([0.76844737, 0.7697189 , 0.77435797, 0.76097539, 0.76603221]),
#  'test_mse': array([0.98683983, 0.99538824, 1.00467498, 0.9742226 , 0.97941684]),
#  'test_fcp': array([0.64917857, 0.65713885, 0.64975948, 0.65656734, 0.65100219]),
#  'fit_time': (0.19117474555969238,
#   0.23998212814331055,
#   0.23409819602966309,
#   0.3098313808441162,
#   0.20397305488586426),
#  'test_time': (1.6049344539642334,
#   1.424264907836914,
#   2.374554395675659,
#   1.5334293842315674,
#   1.4046790599822998)}

# %%
cross_validate(algo_knnbasic_ib_msd, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0029  0.9881  0.9907  0.9968  1.0011  0.9959  0.0057
# MAE (testset)     0.7815  0.7694  0.7700  0.7755  0.7793  0.7751  0.0048
# MSE (testset)     1.0058  0.9764  0.9816  0.9936  1.0021  0.9919  0.0114
# FCP (testset)     0.4526  0.4585  0.4479  0.4484  0.4475  0.4510  0.0042
# Fit time          6.61    6.69    6.69    6.57    6.28    6.57    0.15
# Test time         6.87    6.64    6.79    7.14    7.32    6.95    0.24
# {'test_rmse': array([1.00288494, 0.98813919, 0.99074713, 0.99681945, 1.00106144]),
#  'test_mae': array([0.78146752, 0.76939989, 0.77000905, 0.77551241, 0.77927578]),
#  'test_mse': array([1.0057782 , 0.97641906, 0.98157988, 0.99364902, 1.002124  ]),
#  'test_fcp': array([0.4525724 , 0.4585494 , 0.44793829, 0.44841476, 0.44754668]),
#  'fit_time': (6.605316638946533,
#   6.691845893859863,
#   6.689788103103638,
#   6.566170692443848,
#   6.283113479614258),
#  'test_time': (6.871513366699219,
#   6.6409218311309814,
#   6.7938392162323,
#   7.1434314250946045,
#   7.319519758224487)}

# %%
cross_validate(algo_knnbasic_ub_msd, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9843  0.9999  0.9980  0.9862  1.0038  0.9944  0.0078
# MAE (testset)     0.7614  0.7727  0.7661  0.7626  0.7764  0.7679  0.0058
# MSE (testset)     0.9688  0.9998  0.9959  0.9726  1.0076  0.9890  0.0154
# FCP (testset)     0.6561  0.6565  0.6444  0.6509  0.6574  0.6531  0.0049
# Fit time          0.19    0.26    0.25    0.34    0.21    0.25    0.05
# Test time         1.67    1.70    3.13    1.80    1.48    1.96    0.60
# {'test_rmse': array([0.98427568, 0.99991653, 0.99796631, 0.98622346, 1.00379798]),
#  'test_mae': array([0.76140878, 0.7727365 , 0.76614237, 0.76261231, 0.77638026]),
#  'test_mse': array([0.96879862, 0.99983307, 0.99593676, 0.97263672, 1.00761038]),
#  'test_fcp': array([0.65607582, 0.65653202, 0.64444405, 0.65091408, 0.65736154]),
#  'fit_time': (0.1916971206665039,
#   0.26307058334350586,
#   0.2453153133392334,
#   0.33958005905151367,
#   0.2089078426361084),
#  'test_time': (1.6669971942901611,
#   1.6995785236358643,
#   3.128413200378418,
#   1.804898738861084,
#   1.4766783714294434)}

# %%
cross_validate(algo_knnbasic_ib_prs, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9970  1.0001  0.9965  0.9939  0.9959  0.9967  0.0020
# MAE (testset)     0.7765  0.7777  0.7730  0.7741  0.7761  0.7755  0.0017
# MSE (testset)     0.9940  1.0002  0.9931  0.9879  0.9918  0.9934  0.0040
# FCP (testset)     0.4608  0.4527  0.4536  0.4453  0.4566  0.4538  0.0051
# Fit time          9.50    6.45    6.26    6.54    7.29    7.21    1.20
# Test time         8.23    8.52    8.49    8.01    7.17    8.09    0.49
# {'test_rmse': array([0.99700084, 1.00010647, 0.99653604, 0.99393622, 0.995894  ]),
#  'test_mae': array([0.77652234, 0.77769538, 0.77296839, 0.7740567 , 0.77613317]),
#  'test_mse': array([0.99401067, 1.00021295, 0.99308408, 0.9879092 , 0.99180485]),
#  'test_fcp': array([0.46081648, 0.45272493, 0.45360592, 0.44525282, 0.45661395]),
#  'fit_time': (9.503350496292114,
#   6.454232454299927,
#   6.263867139816284,
#   6.53687310218811,
#   7.285096168518066),
#  'test_time': (8.22743558883667,
#   8.524821519851685,
#   8.493083000183105,
#   8.01101303100586,
#   7.173703193664551)}

# %%
cross_validate(algo_knnbasic_ub_prs, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9957  0.9892  0.9957  0.9932  0.9973  0.9942  0.0028
# MAE (testset)     0.7694  0.7651  0.7689  0.7659  0.7707  0.7680  0.0021
# MSE (testset)     0.9915  0.9785  0.9914  0.9864  0.9947  0.9885  0.0057
# FCP (testset)     0.6511  0.6532  0.6607  0.6444  0.6507  0.6520  0.0053
# Fit time          0.18    0.23    0.31    0.23    0.22    0.24    0.04
# Test time         1.47    1.66    2.46    1.64    1.46    1.74    0.37
# {'test_rmse': array([0.99574435, 0.98919073, 0.99570526, 0.99316708, 0.99732848]),
#  'test_mae': array([0.76936342, 0.76512168, 0.7688999 , 0.76593554, 0.77073706]),
#  'test_mse': array([0.99150682, 0.97849831, 0.99142897, 0.98638084, 0.9946641 ]),
#  'test_fcp': array([0.65112013, 0.65316231, 0.6607118 , 0.64435231, 0.65067416]),
#  'fit_time': (0.1836106777191162,
#   0.23225903511047363,
#   0.31435060501098633,
#   0.2290031909942627,
#   0.22312259674072266),
#  'test_time': (1.4695982933044434,
#   1.656184434890747,
#   2.462367534637451,
#   1.6404502391815186,
#   1.4649882316589355)}

# %% [markdown]
# *Erstellung Algorithmus KNNWithMeans*
#
# Die Algorithmen werden mit den bereits konfigurierten Ähnlichkeits Optionen erstellt.

# %%
algo_withMeans_ib_cos = KNNWithMeans(sim_options=sim_options_knnbasic_ib_cos, k = 40) #Quelle 8

# %%
algo_withMeans_ub_cos = KNNWithMeans(sim_options=sim_options_knnbasic_ub_cos, k = 40) #Quelle 8

# %%
algo_withMeans_ib_msd = KNNWithMeans(sim_options=sim_options_knnbasic_ib_msd, k = 40) #Quelle 8

# %%
algo_withMeans_ub_msd = KNNWithMeans(sim_options=sim_options_knnbasic_ub_msd, k = 40) #Quelle 8

# %%
algo_withMeans_ib_prs = KNNWithMeans(sim_options=sim_options_knnbasic_ib_prs, k = 40) #Quelle 8

# %%
algo_withMeans_ub_prs = KNNWithMeans(sim_options=sim_options_knnbasic_ub_prs, k = 40) #Quelle 8

# %% [markdown]
# *Evaluierung Metriken KNNWithMeans*
#
# Die Cross Validierung wird konfiguriert und durchgeführt.

# %%
cross_validate(algo_withMeans_ib_cos, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9170  0.9308  0.9326  0.9326  0.9257  0.9277  0.0059
# MAE (testset)     0.7085  0.7128  0.7147  0.7113  0.7043  0.7103  0.0036
# MSE (testset)     0.8408  0.8664  0.8697  0.8697  0.8570  0.8607  0.0110
# FCP (testset)     0.6441  0.6372  0.6377  0.6358  0.6391  0.6388  0.0029
# Fit time          7.01    6.79    6.47    6.35    6.98    6.72    0.27
# Test time         7.79    8.39    8.52    8.41    9.67    8.56    0.61
# {'test_rmse': array([0.91695781, 0.9308081 , 0.93256609, 0.93256391, 0.9257323 ]),
#  'test_mae': array([0.70853831, 0.7128252 , 0.71471311, 0.71134606, 0.7043212 ]),
#  'test_mse': array([0.84081162, 0.86640371, 0.86967951, 0.86967544, 0.85698029]),
#  'test_fcp': array([0.64410294, 0.63717109, 0.63765682, 0.63575253, 0.63911478]),
#  'fit_time': (7.006377696990967,
#   6.7918009757995605,
#   6.468920707702637,
#   6.345012664794922,
#   6.97597599029541),
#  'test_time': (7.78861665725708,
#   8.386537313461304,
#   8.524377346038818,
#   8.414377689361572,
#   9.672109127044678)}

# %%
cross_validate(algo_withMeans_ub_cos, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9264  0.9242  0.9237  0.9190  0.9265  0.9240  0.0027
# MAE (testset)     0.7100  0.7072  0.7068  0.7042  0.7114  0.7079  0.0025
# MSE (testset)     0.8581  0.8542  0.8533  0.8445  0.8585  0.8537  0.0050
# FCP (testset)     0.6334  0.6365  0.6421  0.6414  0.6368  0.6380  0.0033
# Fit time          0.25    0.24    0.27    0.25    0.41    0.28    0.06
# Test time         1.58    1.87    1.64    2.39    1.88    1.87    0.28
# {'test_rmse': array([0.92635359, 0.92424108, 0.92371564, 0.91897846, 0.92652871]),
#  'test_mae': array([0.70996355, 0.70724029, 0.70677541, 0.70416345, 0.71138853]),
#  'test_mse': array([0.85813097, 0.85422157, 0.85325059, 0.84452142, 0.85845545]),
#  'test_fcp': array([0.63335701, 0.63649177, 0.64212889, 0.64138152, 0.63683464]),
#  'fit_time': (0.24605584144592285,
#   0.24060606956481934,
#   0.27387332916259766,
#   0.2538588047027588,
#   0.40531396865844727),
#  'test_time': (1.5836217403411865,
#   1.8656530380249023,
#   1.6407113075256348,
#   2.3856871128082275,
#   1.8813207149505615)}

# %%
cross_validate(algo_withMeans_ib_msd, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9267  0.9325  0.9262  0.9247  0.9267  0.9274  0.0027
# MAE (testset)     0.7103  0.7118  0.7118  0.7086  0.7088  0.7102  0.0014
# MSE (testset)     0.8588  0.8696  0.8578  0.8551  0.8587  0.8600  0.0050
# FCP (testset)     0.6445  0.6359  0.6400  0.6334  0.6414  0.6390  0.0039
# Fit time          7.02    7.25    7.16    7.00    6.63    7.01    0.21
# Test time         7.46    6.95    7.13    7.19    8.28    7.40    0.47
# {'test_rmse': array([0.92672963, 0.93251366, 0.92619489, 0.92469669, 0.92665468]),
#  'test_mae': array([0.71030628, 0.71175163, 0.71182821, 0.70855512, 0.70876227]),
#  'test_mse': array([0.85882781, 0.86958173, 0.85783698, 0.85506396, 0.8586889 ]),
#  'test_fcp': array([0.64451373, 0.63591935, 0.63997835, 0.63340183, 0.64140772]),
#  'fit_time': (7.017919301986694,
#   7.2506325244903564,
#   7.161374807357788,
#   6.995140314102173,
#   6.633352518081665),
#  'test_time': (7.457540035247803,
#   6.951714992523193,
#   7.1283860206604,
#   7.190501689910889,
#   8.276057004928589)}

# %%
cross_validate(algo_withMeans_ub_msd, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9217  0.9235  0.9180  0.9148  0.9300  0.9216  0.0052
# MAE (testset)     0.7066  0.7066  0.7055  0.7019  0.7119  0.7065  0.0032
# MSE (testset)     0.8495  0.8529  0.8427  0.8368  0.8649  0.8494  0.0096
# FCP (testset)     0.6309  0.6445  0.6381  0.6378  0.6428  0.6388  0.0048
# Fit time          0.23    0.27    0.25    0.41    0.27    0.28    0.06
# Test time         1.58    1.58    2.26    1.74    1.54    1.74    0.27
# {'test_rmse': array([0.92167691, 0.92354745, 0.91801199, 0.91476637, 0.9300064 ]),
#  'test_mae': array([0.7065966 , 0.70658057, 0.70554596, 0.70190351, 0.71190378]),
#  'test_mse': array([0.84948832, 0.85293989, 0.842746  , 0.83679752, 0.86491191]),
#  'test_fcp': array([0.63085058, 0.6445445 , 0.63805726, 0.63782246, 0.64279253]),
#  'fit_time': (0.2269608974456787,
#   0.265275239944458,
#   0.25148987770080566,
#   0.40928101539611816,
#   0.26501917839050293),
#  'test_time': (1.5782020092010498,
#   1.577587366104126,
#   2.2591347694396973,
#   1.7384617328643799,
#   1.5415749549865723)}

# %%
cross_validate(algo_withMeans_ib_prs, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9361  0.9204  0.9322  0.9263  0.9236  0.9277  0.0057
# MAE (testset)     0.7166  0.7086  0.7132  0.7060  0.7073  0.7103  0.0040
# MSE (testset)     0.8763  0.8472  0.8690  0.8581  0.8531  0.8607  0.0106
# FCP (testset)     0.6385  0.6388  0.6346  0.6367  0.6437  0.6385  0.0030
# Fit time          7.76    6.41    6.27    6.76    7.14    6.87    0.54
# Test time         8.24    8.70    8.39    7.99    7.01    8.06    0.58
# {'test_rmse': array([0.93610722, 0.92041194, 0.93218292, 0.92633245, 0.92362907]),
#  'test_mae': array([0.71661512, 0.7085527 , 0.71322265, 0.70602062, 0.70725633]),
#  'test_mse': array([0.87629672, 0.84715813, 0.868965  , 0.85809181, 0.85309066]),
#  'test_fcp': array([0.6385441 , 0.63881924, 0.63457598, 0.63666146, 0.64365287]),
#  'fit_time': (7.760527610778809,
#   6.410288333892822,
#   6.26517915725708,
#   6.76216197013855,
#   7.139211177825928),
#  'test_time': (8.23543667793274,
#   8.695966243743896,
#   8.393161058425903,
#   7.988432884216309,
#   7.007168292999268)}

# %%
cross_validate(algo_withMeans_ub_prs, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9231  0.9240  0.9252  0.9269  0.9208  0.9240  0.0020
# MAE (testset)     0.7083  0.7070  0.7075  0.7099  0.7063  0.7078  0.0012
# MSE (testset)     0.8522  0.8537  0.8560  0.8591  0.8478  0.8538  0.0038
# FCP (testset)     0.6393  0.6375  0.6361  0.6389  0.6363  0.6376  0.0013
# Fit time          0.22    0.25    0.26    0.25    0.24    0.25    0.01
# Test time         1.58    1.55    1.54    2.87    1.54    1.82    0.53
# {'test_rmse': array([0.9231223 , 0.92397492, 0.9252181 , 0.92685417, 0.92077691]),
#  'test_mae': array([0.70828341, 0.70698631, 0.70750771, 0.70987301, 0.70632128]),
#  'test_mse': array([0.85215479, 0.85372966, 0.85602853, 0.85905866, 0.84783011]),
#  'test_fcp': array([0.63931441, 0.63747862, 0.63609079, 0.63889721, 0.63631555]),
#  'fit_time': (0.2209491729736328,
#   0.2547585964202881,
#   0.25505518913269043,
#   0.2541365623474121,
#   0.2410593032836914),
#  'test_time': (1.5802702903747559,
#   1.5536060333251953,
#   1.543687105178833,
#   2.871774911880493,
#   1.5439534187316895)}

# %% [markdown]
# *Generierung der Random Empfehlungen*

# %%
algo = NormalPredictor() #Quelle 8

# %%
cross_validate(algo, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Evaluating RMSE, MAE, MSE, FCP of algorithm NormalPredictor on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.4424  1.4434  1.4343  1.4454  1.4480  1.4427  0.0046
# MAE (testset)     1.1522  1.1464  1.1415  1.1517  1.1570  1.1498  0.0053
# MSE (testset)     2.0805  2.0834  2.0572  2.0893  2.0967  2.0814  0.0133
# FCP (testset)     0.4899  0.4924  0.5039  0.4931  0.4956  0.4950  0.0048
# Fit time          0.17    0.19    0.14    0.13    0.14    0.15    0.02
# Test time         0.26    0.14    0.17    0.18    0.08    0.16    0.06
# {'test_rmse': array([1.44240824, 1.44338561, 1.43430543, 1.44544513, 1.4479835 ]),
#  'test_mae': array([1.15224042, 1.14637582, 1.14151978, 1.15171665, 1.15696631]),
#  'test_mse': array([2.08054153, 2.08336203, 2.05723207, 2.08931164, 2.09665623]),
#  'test_fcp': array([0.48985569, 0.49242146, 0.5038924 , 0.4931066 , 0.49558479]),
#  'fit_time': (0.16885590553283691,
#   0.18993091583251953,
#   0.13603472709655762,
#   0.13059687614440918,
#   0.1350843906402588),
#  'test_time': (0.2588644027709961,
#   0.13811945915222168,
#   0.16546869277954102,
#   0.17620539665222168,
#   0.0778205394744873)}

# %% [markdown]
# *Generierung von Top N Empfehlungen*

# %%
trainset = data.build_full_trainset() #Quelle 10
algo.fit(trainset) #Quelle 10

# %%
def get_collaborative_filtering_recommendations(user_id, top_n): #Quelle 11
    testset = trainset.build_anti_testset()
    testset = filter(lambda x: x[0] == user_id, testset)
    predictions = algo.test(testset)
    predictions.sort(key=lambda x: x.est, reverse=True)
    recommendations = [prediction.iid for prediction in predictions[:top_n]]
    return recommendations

# %%
user_id = 10
top_n = 10
recommendations = get_collaborative_filtering_recommendations(user_id, top_n)

# %%
recommendations
# Out:
# [2150, 62, 208, 235, 273, 317, 509, 60, 1580, 1721]

# %%
print(f"Empfehlungen für Nutzer mit ID: {user_id}:")
for i, recommendation in enumerate(recommendations):
    print(f"{i + 1}. Movie ID: {recommendation}")
# Out:
# Empfehlungen für Nutzer mit ID: 10:
# 1. Movie ID: 2150
# 2. Movie ID: 62
# 3. Movie ID: 208
# 4. Movie ID: 235
# 5. Movie ID: 273
# 6. Movie ID: 317
# 7. Movie ID: 509
# 8. Movie ID: 60
# 9. Movie ID: 1580
# 10. Movie ID: 1721

# %% [markdown]
# Quellenverzeichnis:
#
#
# Quelle 1: pypi.org, Installation scikit-surprise, letzter Aufruf: 18.07.2024,
# Link:https://pypi.org/project/scikit-surprise/
#
#
# Quelle 2: w3schools, Pandas Getting Started, letzter Aufruf: 18.07.2024,
# Link:https://www.w3schools.com/python/pandas/pandas_getting_started.asp
#
#
# Quelle 3: Read the Docs, Surprise Dokumentation, Getting started, letzter Aufruf: 18.07.2024 Link: https://surprise.readthedocs.io/en/stable/getting_started.html#getting-started
#
# Quelle 4: w3schools, Pandas, letzter Aufruf: 18.07.2024, Link:https://www.w3schools.com/python/pandas/pandas_csv.asp
#
# Quelle 5: Read the Docs, Surprise Dokumentation, Reader, letzter Aufruf: 18.07.2024, Link:https://surprise.readthedocs.io/en/stable/reader.html
#
# Quelle 6: Read the Docs, Surprise Dokumentation, Ähnlichkeits Metriken konfigurieren, letzter Aufruf: 18.07.2024,
# Link: https://surprise.readthedocs.io/en/stable/prediction_algorithms.html#similarity-measures-configuration
#
# Quelle 7: Read the Docs, Surprise Dokumentation, Ähnlichkeits Metriken Auswahl, letzter Aufruf: 18.07.2024, Link: https://surprise.readthedocs.io/en/stable/similarities.html
#
# Quelle 8: Read the Docs, Surprise Dokumentation, Algorithmen Auswahl, letzter Aufruf: 18.07.2024, Link: https://surprise.readthedocs.io/en/stable/prediction_algorithms_package.html
#
# Quelle 9: Read the Docs, Surprise Dokumentation, Evaluationsverfahren, letzter Aufruf: 18.07.2024, Link: https://surprise.readthedocs.io/en/stable/accuracy.html
#
# Quelle 10: Read the Docs, Surprise Dokumentation,letzter Aufruf: 18.07.2024, Link: https://surprise.readthedocs.io/en/stable/trainset.html
#
# Quelle 11, AMAN KHARWAL, thecleverprogrammer, letzter Aufruf: 18.07.2024, Link: https://thecleverprogrammer.com/2023/06/05/hybrid-recommendation-system-using-python/
