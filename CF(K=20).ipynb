# %% [markdown]
# **Implementierung Kollaboratives speicherbasiertes System mit K = 20**

# %% [markdown]
# *Installation Surprise Bibliothek*

# %%
pip install scikit-surprise # Quelle 1
# Out:
# Collecting scikit-surprise
#   Downloading scikit_surprise-1.1.4.tar.gz (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 1.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.25.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.4)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (pyproject.toml) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp310-cp310-linux_x86_64.whl size=2357229 sha256=37e8fbb3f320a12880e0ef39d60f15493d8fd5c97cb4fc2fd0c39f953180dd1a
#   Stored in directory: /root/.cache/pip/wheels/4b/3f/df/6acbf0a40397d9bf3ff97f582cc22fb9ce66adde75bc71fd54
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.4

# %% [markdown]
# *Import benötigte Bibliotheken*
#
#
# Importiert werden die für die Umsetzung benötigten Python Bibliotheken Pandas und Surprise

# %%
import pandas as pd # Quelle 2
from surprise.model_selection import cross_validate #Quelle 3
from surprise import Dataset, Reader, accuracy, KNNBasic, NormalPredictor, KNNWithMeans #Quelle 3

# %% [markdown]
# *Datenvorverarbeitung*
#
# Die Bewertungsdaten werden eingelesen und in ein Format überführt, mit welchem Surprise arbeiten kann.

# %%
ratings = pd.read_csv('ratings.csv') # Quelle 4

# %%
reader = Reader(rating_scale=(0.5, 5.0)) # Quelle 5
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader) #Quelle 5

# %% [markdown]
# *Konfiguration der Ähnlichkeit Einstellungen*
#
# Die Ähnlichkeits Konfigurationen werden erstellt und intitialisiert.

# %%
#Kosinus Ähnlichkeit Item Based
sim_options_knnbasic_ib_cos = {"name": "cosine", 'user_based': False} # Quelle 6,7

# %%
#Kosinus Ähnlichkeit User Based
sim_options_knnbasic_ub_cos = {"name": "cosine", 'user_based': True} # Quelle 6,7

# %%
#Kosinus Ähnlichkeit Item Based
sim_options_knnbasic_ib_msd = {"name": "cosine", 'user_based': False} # Quelle 6,7

# %%
#Kosinus Ähnlichkeit User Based
sim_options_knnbasic_ub_msd = {"name": "cosine", 'user_based': True} # Quelle 6,7

# %%
#Kosinus Ähnlichkeit Item Based
sim_options_knnbasic_ib_prs = {"name": "cosine", 'user_based': False} # Quelle 6,7

# %%
#Kosinus Ähnlichkeit User Based
sim_options_knnbasic_ub_prs = {"name": "cosine", 'user_based': True} # Quelle 6,7

# %% [markdown]
# *Erstellung Algorithmus KNNBasic*
#
# Die Algorithmen werden mit den bereits konfigurierten Ähnlichkeits Optionen erstellt.

# %%
algo_knnbasic_ib_cos = KNNBasic(sim_options=sim_options_knnbasic_ib_cos, k = 20) #Quelle 8

# %%
algo_knnbasic_ub_cos = KNNBasic(sim_options=sim_options_knnbasic_ub_cos, k = 20) #Quelle 8

# %%
algo_knnbasic_ib_msd = KNNBasic(sim_options=sim_options_knnbasic_ib_msd, k = 20) #Quelle 8

# %%
algo_knnbasic_ub_msd = KNNBasic(sim_options=sim_options_knnbasic_ub_msd, k = 20) #Quelle 8

# %%
algo_knnbasic_ib_prs = KNNBasic(sim_options=sim_options_knnbasic_ib_prs, k = 20) #Quelle 8

# %%
algo_knnbasic_ub_prs = KNNBasic(sim_options=sim_options_knnbasic_ub_prs, k = 20) #Quelle 8

# %% [markdown]
# *Evaluierungs Parameter: RMSE, MAE, MSE, FCP, Test-Time, Train-Time (KNNBasic)*
#
# Die Cross Validierung wird konfiguriert und durchgeführt.

# %%
cross_validate(algo_knnbasic_ib_cos, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0168  1.0114  1.0171  1.0230  1.0231  1.0183  0.0044
# MAE (testset)     0.7951  0.7924  0.7927  0.7985  0.7979  0.7953  0.0025
# MSE (testset)     1.0339  1.0229  1.0344  1.0465  1.0468  1.0369  0.0089
# FCP (testset)     0.4441  0.4465  0.4576  0.4422  0.4528  0.4487  0.0057
# Fit time          6.43    6.19    6.13    6.27    6.34    6.27    0.11
# Test time         7.22    7.22    6.98    6.77    6.76    6.99    0.20
# {'test_rmse': array([1.01679074, 1.01140798, 1.01706349, 1.022971  , 1.02314701]),
#  'test_mae': array([0.79505141, 0.79240652, 0.7926853 , 0.79853609, 0.79787828]),
#  'test_mse': array([1.0338634 , 1.02294609, 1.03441815, 1.04646967, 1.0468298 ]),
#  'test_fcp': array([0.44413874, 0.44650952, 0.45757768, 0.44223452, 0.4528109 ]),
#  'fit_time': (6.4336464405059814,
#   6.1948561668396,
#   6.131014108657837,
#   6.2700653076171875,
#   6.341813564300537),
#  'test_time': (7.220327854156494,
#   7.2238523960113525,
#   6.984407663345337,
#   6.7722413539886475,
#   6.760367393493652)}

# %%
cross_validate(algo_knnbasic_ub_cos, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9989  0.9985  1.0029  0.9893  0.9973  0.9974  0.0045
# MAE (testset)     0.7698  0.7696  0.7706  0.7615  0.7699  0.7683  0.0034
# MSE (testset)     0.9979  0.9971  1.0059  0.9788  0.9947  0.9949  0.0089
# FCP (testset)     0.6507  0.6570  0.6540  0.6452  0.6446  0.6503  0.0048
# Fit time          0.21    0.23    0.34    0.24    0.22    0.25    0.05
# Test time         1.41    1.28    2.12    1.42    1.27    1.50    0.32
# {'test_rmse': array([0.99893828, 0.99854859, 1.00292294, 0.98932553, 0.99734071]),
#  'test_mae': array([0.76982605, 0.76961507, 0.77058228, 0.76152996, 0.76993029]),
#  'test_mse': array([0.99787769, 0.99709928, 1.00585441, 0.97876501, 0.9946885 ]),
#  'test_fcp': array([0.6506961 , 0.65696465, 0.65398937, 0.64518474, 0.6445821 ]),
#  'fit_time': (0.21393489837646484,
#   0.2326505184173584,
#   0.33693671226501465,
#   0.24070310592651367,
#   0.21537089347839355),
#  'test_time': (1.4144024848937988,
#   1.2794225215911865,
#   2.1186764240264893,
#   1.4183120727539062,
#   1.2668144702911377)}

# %%
cross_validate(algo_knnbasic_ib_msd, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0215  1.0108  1.0211  1.0091  1.0225  1.0170  0.0058
# MAE (testset)     0.7957  0.7899  0.7965  0.7903  0.7975  0.7940  0.0032
# MSE (testset)     1.0435  1.0216  1.0427  1.0183  1.0454  1.0343  0.0118
# FCP (testset)     0.4547  0.4411  0.4417  0.4488  0.4491  0.4471  0.0051
# Fit time          6.71    6.86    6.78    6.82    6.79    6.79    0.05
# Test time         6.22    6.17    6.26    6.33    6.20    6.24    0.06
# {'test_rmse': array([1.02151775, 1.01075829, 1.02113307, 1.00909933, 1.0224581 ]),
#  'test_mae': array([0.79566335, 0.78994151, 0.79652385, 0.79033358, 0.79750569]),
#  'test_mse': array([1.0434985 , 1.02163233, 1.04271275, 1.01828145, 1.04542056]),
#  'test_fcp': array([0.45470472, 0.44105271, 0.44174097, 0.44875416, 0.44913372]),
#  'fit_time': (6.7121241092681885,
#   6.85518741607666,
#   6.782141447067261,
#   6.82024621963501,
#   6.789501905441284),
#  'test_time': (6.2210094928741455,
#   6.172425031661987,
#   6.262971639633179,
#   6.334233045578003,
#   6.20215916633606)}

# %%
cross_validate(algo_knnbasic_ub_msd, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9928  0.9905  1.0098  0.9981  0.9930  0.9968  0.0069
# MAE (testset)     0.7630  0.7659  0.7772  0.7691  0.7659  0.7682  0.0049
# MSE (testset)     0.9857  0.9811  1.0196  0.9961  0.9860  0.9937  0.0139
# FCP (testset)     0.6528  0.6503  0.6539  0.6512  0.6583  0.6533  0.0028
# Fit time          0.30    0.22    0.21    0.21    0.21    0.23    0.04
# Test time         1.87    1.27    1.40    1.25    1.42    1.44    0.22
# {'test_rmse': array([0.99282288, 0.99048798, 1.00976751, 0.99806763, 0.99295569]),
#  'test_mae': array([0.76300568, 0.76588953, 0.77715681, 0.76912457, 0.76592586]),
#  'test_mse': array([0.98569728, 0.98106644, 1.01963042, 0.996139  , 0.98596099]),
#  'test_fcp': array([0.65281759, 0.65032217, 0.65390047, 0.65118506, 0.65832145]),
#  'fit_time': (0.30402159690856934,
#   0.21938037872314453,
#   0.2145528793334961,
#   0.21019339561462402,
#   0.211014986038208),
#  'test_time': (1.8658685684204102,
#   1.274444818496704,
#   1.3984012603759766,
#   1.2516329288482666,
#   1.4222791194915771)}

# %%
cross_validate(algo_knnbasic_ib_prs, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0206  1.0194  1.0178  1.0107  1.0222  1.0181  0.0040
# MAE (testset)     0.7935  0.7967  0.7943  0.7893  0.7946  0.7937  0.0024
# MSE (testset)     1.0417  1.0391  1.0359  1.0215  1.0450  1.0366  0.0081
# FCP (testset)     0.4419  0.4401  0.4425  0.4515  0.4563  0.4465  0.0063
# Fit time          5.88    6.09    5.89    5.76    5.84    5.89    0.11
# Test time         6.62    6.94    7.18    9.05    7.62    7.48    0.85
# {'test_rmse': array([1.02064156, 1.01936259, 1.01776978, 1.01067491, 1.02223796]),
#  'test_mae': array([0.79353451, 0.79669749, 0.79428928, 0.78932185, 0.79456058]),
#  'test_mse': array([1.0417092 , 1.03910008, 1.03585533, 1.02146378, 1.04497045]),
#  'test_fcp': array([0.4418676 , 0.44009659, 0.44251785, 0.45153854, 0.45628856]),
#  'fit_time': (5.8755528926849365,
#   6.087357521057129,
#   5.885064363479614,
#   5.760398864746094,
#   5.839841604232788),
#  'test_time': (6.615401983261108,
#   6.9381937980651855,
#   7.177152872085571,
#   9.045835733413696,
#   7.62336540222168)}

# %%
cross_validate(algo_knnbasic_ub_prs, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9936  0.9893  1.0005  1.0005  1.0065  0.9981  0.0060
# MAE (testset)     0.7666  0.7648  0.7710  0.7686  0.7769  0.7696  0.0042
# MSE (testset)     0.9872  0.9788  1.0010  1.0011  1.0131  0.9962  0.0120
# FCP (testset)     0.6628  0.6581  0.6605  0.6551  0.6415  0.6556  0.0075
# Fit time          0.22    0.22    0.34    0.34    0.32    0.29    0.06
# Test time         1.29    1.87    2.33    1.57    1.91    1.80    0.35
# {'test_rmse': array([0.9935624 , 0.98932602, 1.00048021, 1.00053035, 1.00650579]),
#  'test_mae': array([0.76660599, 0.7648028 , 0.77104243, 0.76857907, 0.77688908]),
#  'test_mse': array([0.98716625, 0.97876598, 1.00096065, 1.00106098, 1.0130539 ]),
#  'test_fcp': array([0.66283092, 0.65810413, 0.66049655, 0.65510162, 0.64149131]),
#  'fit_time': (0.21621322631835938,
#   0.22438549995422363,
#   0.3421478271484375,
#   0.3439757823944092,
#   0.31593990325927734),
#  'test_time': (1.2925405502319336,
#   1.8669078350067139,
#   2.3349905014038086,
#   1.5744671821594238,
#   1.908271074295044)}

# %% [markdown]
# *Erstellung Algorithmus KNNWithMeans*
#
# Die Algorithmen werden mit den bereits konfigurierten Ähnlichkeits Optionen erstellt.

# %%
algo_withMeans_ib_cos = KNNWithMeans(sim_options=sim_options_knnbasic_ib_cos, k = 20) #Quelle 8

# %%
algo_withMeans_ub_cos = KNNWithMeans(sim_options=sim_options_knnbasic_ub_cos, k = 20) #Quelle 8

# %%
algo_withMeans_ib_msd = KNNWithMeans(sim_options=sim_options_knnbasic_ib_msd, k = 20) #Quelle 8

# %%
algo_withMeans_ub_msd = KNNWithMeans(sim_options=sim_options_knnbasic_ub_msd, k = 20) #Quelle 8

# %%
algo_withMeans_ib_prs = KNNWithMeans(sim_options=sim_options_knnbasic_ib_prs, k = 20) #Quelle 8

# %%
algo_withMeans_ub_prs = KNNWithMeans(sim_options=sim_options_knnbasic_ub_prs, k = 20) #Quelle 8

# %% [markdown]
# *Evaluierung Metriken KNNWithMeans*
#
# Die Cross Validierung wird konfiguriert und durchgeführt.

# %%
cross_validate(algo_withMeans_ib_cos, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9385  0.9382  0.9347  0.9496  0.9288  0.9380  0.0068
# MAE (testset)     0.7215  0.7190  0.7172  0.7256  0.7118  0.7190  0.0046
# MSE (testset)     0.8807  0.8803  0.8737  0.9017  0.8627  0.8798  0.0128
# FCP (testset)     0.6343  0.6311  0.6343  0.6291  0.6397  0.6337  0.0036
# Fit time          9.42    6.86    6.91    7.33    7.42    7.59    0.94
# Test time         7.76    7.70    7.07    6.43    6.43    7.08    0.58
# {'test_rmse': array([0.93847723, 0.9382286 , 0.93470664, 0.94960325, 0.9288108 ]),
#  'test_mae': array([0.7214583 , 0.71902555, 0.71722319, 0.7255506 , 0.71175599]),
#  'test_mse': array([0.88073951, 0.88027291, 0.87367651, 0.90174633, 0.8626895 ]),
#  'test_fcp': array([0.63432094, 0.63110474, 0.63428498, 0.62906708, 0.6396556 ]),
#  'fit_time': (9.422382593154907,
#   6.862832307815552,
#   6.90752387046814,
#   7.334473609924316,
#   7.419165372848511),
#  'test_time': (7.762402296066284,
#   7.701672077178955,
#   7.073500156402588,
#   6.4330360889434814,
#   6.4299187660217285)}

# %%
cross_validate(algo_withMeans_ub_cos, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9246  0.9168  0.9247  0.9306  0.9372  0.9268  0.0068
# MAE (testset)     0.7108  0.7047  0.7082  0.7153  0.7198  0.7117  0.0053
# MSE (testset)     0.8549  0.8406  0.8551  0.8660  0.8784  0.8590  0.0126
# FCP (testset)     0.6386  0.6391  0.6338  0.6354  0.6250  0.6344  0.0051
# Fit time          0.43    0.30    0.39    0.28    0.40    0.36    0.06
# Test time         1.94    1.69    2.06    1.42    2.30    1.88    0.30
# {'test_rmse': array([0.9245828 , 0.91684832, 0.92474148, 0.93057999, 0.93722224]),
#  'test_mae': array([0.71075752, 0.70465014, 0.70823793, 0.71526183, 0.71982309]),
#  'test_mse': array([0.85485336, 0.84061084, 0.8551468 , 0.86597911, 0.87838553]),
#  'test_fcp': array([0.63857113, 0.63912199, 0.63379191, 0.63537844, 0.62498472]),
#  'fit_time': (0.4262700080871582,
#   0.29508256912231445,
#   0.3948521614074707,
#   0.275986909866333,
#   0.40019869804382324),
#  'test_time': (1.9365744590759277,
#   1.6868348121643066,
#   2.0647480487823486,
#   1.4186041355133057,
#   2.295579433441162)}

# %%
cross_validate(algo_withMeans_ib_msd, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9368  0.9379  0.9426  0.9359  0.9417  0.9390  0.0027
# MAE (testset)     0.7162  0.7178  0.7211  0.7180  0.7213  0.7189  0.0020
# MSE (testset)     0.8776  0.8796  0.8886  0.8758  0.8869  0.8817  0.0051
# FCP (testset)     0.6363  0.6421  0.6312  0.6438  0.6306  0.6368  0.0054
# Fit time          6.84    7.52    7.43    7.28    7.14    7.24    0.24
# Test time         7.40    6.57    6.45    6.58    6.47    6.69    0.36
# {'test_rmse': array([0.93679441, 0.93787936, 0.94264575, 0.93585704, 0.94172858]),
#  'test_mae': array([0.71621956, 0.71778978, 0.72111246, 0.71801878, 0.72129963]),
#  'test_mse': array([0.87758376, 0.87961769, 0.88858101, 0.8758284 , 0.88685272]),
#  'test_fcp': array([0.63634729, 0.64212404, 0.63122004, 0.64379541, 0.63055669]),
#  'fit_time': (6.83760404586792,
#   7.517797946929932,
#   7.4277448654174805,
#   7.278714179992676,
#   7.135848045349121),
#  'test_time': (7.400758266448975,
#   6.567217826843262,
#   6.451803684234619,
#   6.581920385360718,
#   6.46850848197937)}

# %%
cross_validate(algo_withMeans_ub_msd, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9370  0.9270  0.9206  0.9232  0.9214  0.9258  0.0060
# MAE (testset)     0.7192  0.7129  0.7082  0.7084  0.7085  0.7115  0.0043
# MSE (testset)     0.8780  0.8593  0.8475  0.8522  0.8489  0.8572  0.0112
# FCP (testset)     0.6370  0.6406  0.6394  0.6335  0.6264  0.6354  0.0051
# Fit time          0.26    0.29    0.27    0.27    0.40    0.30    0.05
# Test time         1.47    1.47    1.45    2.25    1.71    1.67    0.31
# {'test_rmse': array([0.93702838, 0.92699112, 0.9205738 , 0.92316357, 0.92136738]),
#  'test_mae': array([0.7192225 , 0.71293909, 0.70819908, 0.70838719, 0.70852472]),
#  'test_mse': array([0.87802218, 0.85931253, 0.84745612, 0.85223098, 0.84891785]),
#  'test_fcp': array([0.63703105, 0.64055608, 0.63944728, 0.63346823, 0.62641962]),
#  'fit_time': (0.25795555114746094,
#   0.2881605625152588,
#   0.2713773250579834,
#   0.273831844329834,
#   0.4048194885253906),
#  'test_time': (1.4664287567138672,
#   1.4696414470672607,
#   1.4466607570648193,
#   2.2547993659973145,
#   1.7055799961090088)}

# %%
cross_validate(algo_withMeans_ib_prs, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9314  0.9382  0.9380  0.9445  0.9359  0.9376  0.0042
# MAE (testset)     0.7120  0.7193  0.7232  0.7254  0.7183  0.7196  0.0046
# MSE (testset)     0.8676  0.8802  0.8798  0.8921  0.8760  0.8791  0.0079
# FCP (testset)     0.6362  0.6364  0.6329  0.6285  0.6372  0.6342  0.0032
# Fit time          7.25    7.14    6.98    6.49    6.32    6.84    0.37
# Test time         6.50    6.77    7.07    8.57    7.91    7.36    0.77
# {'test_rmse': array([0.93143704, 0.93817529, 0.93796337, 0.94450282, 0.93593706]),
#  'test_mae': array([0.71196376, 0.71932697, 0.72322735, 0.72540282, 0.71832653]),
#  'test_mse': array([0.86757496, 0.88017288, 0.87977528, 0.89208557, 0.87597818]),
#  'test_fcp': array([0.63615792, 0.63639469, 0.63287006, 0.62848105, 0.63720282]),
#  'fit_time': (7.247602462768555,
#   7.143137454986572,
#   6.984792709350586,
#   6.490607261657715,
#   6.324783802032471),
#  'test_time': (6.502297401428223,
#   6.773971319198608,
#   7.069487810134888,
#   8.569682359695435,
#   7.909162282943726)}

# %%
cross_validate(algo_withMeans_ub_prs, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE, FCP of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9256  0.9242  0.9297  0.9203  0.9299  0.9260  0.0036
# MAE (testset)     0.7106  0.7107  0.7140  0.7092  0.7107  0.7110  0.0016
# MSE (testset)     0.8568  0.8541  0.8644  0.8469  0.8648  0.8574  0.0067
# FCP (testset)     0.6392  0.6358  0.6293  0.6315  0.6376  0.6347  0.0037
# Fit time          0.25    0.41    0.29    0.30    0.28    0.31    0.05
# Test time         1.85    2.15    1.41    1.68    1.41    1.70    0.28
# {'test_rmse': array([0.92564072, 0.92417303, 0.92974269, 0.92029247, 0.92992257]),
#  'test_mae': array([0.71060432, 0.71069841, 0.71397704, 0.70921489, 0.71068185]),
#  'test_mse': array([0.85681074, 0.85409578, 0.86442147, 0.84693824, 0.86475599]),
#  'test_fcp': array([0.63924182, 0.63582798, 0.6292672 , 0.63147935, 0.63758883]),
#  'fit_time': (0.24968862533569336,
#   0.4067826271057129,
#   0.29012107849121094,
#   0.3030557632446289,
#   0.2790095806121826),
#  'test_time': (1.8453185558319092,
#   2.147339105606079,
#   1.413844347000122,
#   1.6776401996612549,
#   1.4148612022399902)}

# %% [markdown]
# *Generierung der Random Empfehlungen*

# %%
algo = NormalPredictor() #Quelle 8

# %%
cross_validate(algo, data, measures=["RMSE", "MAE", "MSE", "FCP"], cv=5, verbose=True) #Quelle 9
# Out:
# Evaluating RMSE, MAE, MSE, FCP of algorithm NormalPredictor on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.4424  1.4434  1.4343  1.4454  1.4480  1.4427  0.0046
# MAE (testset)     1.1522  1.1464  1.1415  1.1517  1.1570  1.1498  0.0053
# MSE (testset)     2.0805  2.0834  2.0572  2.0893  2.0967  2.0814  0.0133
# FCP (testset)     0.4899  0.4924  0.5039  0.4931  0.4956  0.4950  0.0048
# Fit time          0.17    0.19    0.14    0.13    0.14    0.15    0.02
# Test time         0.26    0.14    0.17    0.18    0.08    0.16    0.06
# {'test_rmse': array([1.44240824, 1.44338561, 1.43430543, 1.44544513, 1.4479835 ]),
#  'test_mae': array([1.15224042, 1.14637582, 1.14151978, 1.15171665, 1.15696631]),
#  'test_mse': array([2.08054153, 2.08336203, 2.05723207, 2.08931164, 2.09665623]),
#  'test_fcp': array([0.48985569, 0.49242146, 0.5038924 , 0.4931066 , 0.49558479]),
#  'fit_time': (0.16885590553283691,
#   0.18993091583251953,
#   0.13603472709655762,
#   0.13059687614440918,
#   0.1350843906402588),
#  'test_time': (0.2588644027709961,
#   0.13811945915222168,
#   0.16546869277954102,
#   0.17620539665222168,
#   0.0778205394744873)}

# %% [markdown]
# *Generierung von Top N Empfehlungen*

# %%
trainset = data.build_full_trainset() #Quelle 10
algo.fit(trainset) #Quelle 10

# %%
def get_collaborative_filtering_recommendations(user_id, top_n): #Quelle 11
    testset = trainset.build_anti_testset()
    testset = filter(lambda x: x[0] == user_id, testset)
    predictions = algo.test(testset)
    predictions.sort(key=lambda x: x.est, reverse=True)
    recommendations = [prediction.iid for prediction in predictions[:top_n]]
    return recommendations

# %%
user_id = 10
top_n = 10
recommendations = get_collaborative_filtering_recommendations(user_id, top_n)

# %%
recommendations
# Out:
# [2150, 62, 208, 235, 273, 317, 509, 60, 1580, 1721]

# %%
print(f"Empfehlungen für Nutzer mit ID: {user_id}:") #Quelle 11
for i, recommendation in enumerate(recommendations):
    print(f"{i + 1}. Movie ID: {recommendation}")
# Out:
# Empfehlungen für Nutzer mit ID: 10:
# 1. Movie ID: 2150
# 2. Movie ID: 62
# 3. Movie ID: 208
# 4. Movie ID: 235
# 5. Movie ID: 273
# 6. Movie ID: 317
# 7. Movie ID: 509
# 8. Movie ID: 60
# 9. Movie ID: 1580
# 10. Movie ID: 1721

# %% [markdown]
# Quellenverzeichnis:
#
#
# Quelle 1: pypi.org, Installation scikit-surprise, letzter Aufruf: 18.07.2024,
# Link:https://pypi.org/project/scikit-surprise/
#
#
# Quelle 2: w3schools, Pandas Getting Started, letzter Aufruf: 18.07.2024,
# Link:https://www.w3schools.com/python/pandas/pandas_getting_started.asp
#
#
# Quelle 3: Read the Docs, Surprise Dokumentation, Getting started, letzter Aufruf: 18.07.2024 Link: https://surprise.readthedocs.io/en/stable/getting_started.html#getting-started
#
# Quelle 4: w3schools, Pandas, letzter Aufruf: 18.07.2024, Link:https://www.w3schools.com/python/pandas/pandas_csv.asp
#
# Quelle 5: Read the Docs, Surprise Dokumentation, Reader, letzter Aufruf: 18.07.2024, Link:https://surprise.readthedocs.io/en/stable/reader.html
#
# Quelle 6: Read the Docs, Surprise Dokumentation, Ähnlichkeits Metriken konfigurieren, letzter Aufruf: 18.07.2024,
# Link: https://surprise.readthedocs.io/en/stable/prediction_algorithms.html#similarity-measures-configuration
#
# Quelle 7: Read the Docs, Surprise Dokumentation, Ähnlichkeits Metriken Auswahl, letzter Aufruf: 18.07.2024, Link: https://surprise.readthedocs.io/en/stable/similarities.html
#
# Quelle 8: Read the Docs, Surprise Dokumentation, Algorithmen Auswahl, letzter Aufruf: 18.07.2024, Link: https://surprise.readthedocs.io/en/stable/prediction_algorithms_package.html
#
# Quelle 9: Read the Docs, Surprise Dokumentation, Evaluationsverfahren, letzter Aufruf: 18.07.2024, Link: https://surprise.readthedocs.io/en/stable/accuracy.html
#
# Quelle 10: Read the Docs, Surprise Dokumentation,letzter Aufruf: 18.07.2024, Link: https://surprise.readthedocs.io/en/stable/trainset.html
#
# Quelle 11, AMAN KHARWAL, thecleverprogrammer, letzter Aufruf: 18.07.2024, Link: https://thecleverprogrammer.com/2023/06/05/hybrid-recommendation-system-using-python/
